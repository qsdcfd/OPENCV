# %% [markdown]
# ## 필터링 이해하기
#
# - 영상의 필터링(image filtering)
#
#   - 영상에서 필요 정보만 통과시키고 원하지 않는 것은 걸러내기
#
#     ![](https://images.velog.io/images/qsdcfd/post/c13576df-016f-4afd-b7f8-d6ba1d5db1c7/image.png)
#
#
# - 주파수 공간에서의 필터링(Frequency domain filtering)
#
# ![](https://images.velog.io/images/qsdcfd/post/5ef1edfc-d5af-40eb-a4d0-1af1eefb9616/image.png)
#
# - 공간적 필터링(Spatial domain filtering)
#
#   - 영상의 픽셀 값 직접 이용
#
#        - 대상 좌표의 픽셀 값과 주변 픽셀 값 동시 사용
#
#     - 주로 마스크 연산이용
#
#       - 마스크 = 커널 = 윈도우 = 탬플릿
#
#
# - 다양한 모양과 크기의 마스크
#
# ![](https://images.velog.io/images/qsdcfd/post/c3592e5f-859c-4c1c-99a4-182dae7d37ca/image.png)
#
# - 마스크의 형태와 값에 따라 필터의 역할 결정
#
#    - 영상 부드럽게 만들기
#
#     - 영상 날카롭게 만들기
#
#     - 에지 검출
#
#     - 잡음 제거
#
#
# - 3* 3 크기의 마스크 이용한 공간적 필터링
#
# ![](https://images.velog.io/images/qsdcfd/post/a255ad85-2a2b-4d93-903e-e0e3f2b40d76/image.png)
#
# - 3 * 3 크기의 마스크를 이용한 공간적 필터링( Con't)
#
#   - (1,1) 좌표에서 필터링
#
#     ![](https://images.velog.io/images/qsdcfd/post/d92cf05b-b52b-4734-b0dc-695addb4257b/image.png)
#
#    - (2,1) 좌표에서 필터링
#
#     ![](https://images.velog.io/images/qsdcfd/post/30731c7d-38c2-41c0-80df-8960e2958a4b/image.png)
#
#
# - 최외곽 픽셀 처리
#
# ![](https://images.velog.io/images/qsdcfd/post/0ad48191-2444-4d2c-b280-37fee9f7b0fb/image.png)
#
# - OpenCV 필터링에서 지원하는 가장 자리 픽셀 확장 방법
#
# ![](https://images.velog.io/images/qsdcfd/post/7906f3a4-ae87-472c-a878-2b0045bc16f5/image.png)
#
# - 기본적인 2D 필터링
#
# ```
# cv2.filter2D(src, ddepth, kernel, dst=None, anchor=None, delta=None,
# borderType=None) -> dst
# ```
#
# - src: 입력 영상
#
# - ddepth: 출력 영상 데이터 타입(ex: cv2.CV_8U, cv2.CV_32F, cv2.CV_64F)으로 -1을 지정하면 src와 같은 타입의 dst영상 생성
#
# - kernel: 필터 마스크 행렬. 실수형
#
# - anchor: 고정점 위치.(-1,-1)이면 필터 중앙을 고정점으로 사용
#
# - delta: 추가적으로 더할 값
#
# - borderType: 가장자리 픽셀 확장 방식
#
# - dst: 출력영상
